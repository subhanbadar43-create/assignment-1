# %%
totalshirts = int(input("Enter total amounts of shirts"))
qualify = 1000
bonuspershirt =20
if totalshirts > qualify:
   extrashirts = totalshirts - qualify
   bonus = extrashirts * bonuspershirt
   print("Qualified for bonus")
   print("extra shirts made are:", extrashirts)
   print("bouns is:",bonus)
else:
    print("employ not qualify.")
    print("Bonus = 0")
# Out:
# Enter total amounts of shirts1200
# Qualified for bonus
# extra shirts made are: 200
# bouns is: 4000
